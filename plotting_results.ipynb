# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
matrix_adress = ".\\Images_and_Data\\Bundle_01\\hdrvdp_09_hdrvdp_matrix.npy"
hdrvdp_matrix = np.load(matrix_adress)

# print(hdrvdp_matrix)

# %%
def get_alias_value_from_matrix_coord(y, x):
    print(f"y: {y}")
    print(f"x: {x}")
    return hdrvdp_matrix[y][x]

# %%
x_values = [x for x in range(32)]
y_values = [x for x in range(18)]

# %%
X, Y = np.meshgrid(x_values, y_values)

# %%
# X

# %%
# Y

# %%
plt.scatter(X, Y)

# %%
ax = plt.axes(projection="3d")
ax.plot_surface(X, Y, hdrvdp_matrix)

# %% [markdown]
# ## 3D Wireframe

# %%
N = 10

x_values = np.linspace(-5, 5, N)
y_values = np.linspace(-5, 5, N)

# %%
X, Y = np.meshgrid(x_values, y_values)
Z = function_z(X, Y)

# %%
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color="black", lw=3)
ax.plot_wireframe(X, Y, Z, color="green", lw=1)
